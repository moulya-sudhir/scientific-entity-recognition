# %% [markdown]
# ## Import necessary libraries

# %%
import sys
sys.path.insert(1,'../')
from webscrape import scrape_pdfs

# %% [markdown]
# ## ACL 2022-2023

# %%
scrape_pdfs('acl', '2022', 200)
# Out:
# IntProgress(value=0, description='acl PDFs...', max=1, style=ProgressStyle(bar_color='green'))
# ...
# Done.

# %%
scrape_pdfs('acl','2023',200)
# Out:
# IntProgress(value=0, description='acl PDFs...', max=200, style=ProgressStyle(bar_color='green'))
# ...
# Done.

# %% [markdown]
# ## EMNLP 2022

# %%
scrape_pdfs('emnlp', '2022', 200)
# Out:
# IntProgress(value=0, description='emnlp PDFs...', max=200, style=ProgressStyle(bar_color='green'))
# ...
# Done.

# %% [markdown]
# ## NAACL 2022

# %%
scrape_pdfs('naacl','2022',200)
# Out:
# IntProgress(value=0, description='naacl PDFs...', max=200, style=ProgressStyle(bar_color='green'))
# ...
# Done.
